# %%
import sqlalchemy

# %%
sqlalchemy.__version__
# Out:
# '2.0.45'

# %%
from sqlalchemy import create_engine, text

# %%
engine = create_engine("sqlite+pysqlite:///:memory:", echo=True)

# %%
with engine.connect() as conn:
    result =  conn.execute(text("select 'hello world'"))
    print(result.all())
# Out:
# 2026-01-18 16:42:37,081 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-18 16:42:37,081 INFO sqlalchemy.engine.Engine select 'hello world'
# 2026-01-18 16:42:37,082 INFO sqlalchemy.engine.Engine [generated in 0.00098s] ()
# [('hello world',)]
# 2026-01-18 16:42:37,083 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
# Commit as you go"
with engine.connect() as conn:
    conn.execute(text("CREATE TABLE some_table (x int, y int)"))
    conn.execute(
        text("INSERT INTO some_table (x, y) VALUES (:x, :y)"), 
        [{"x": 1, "y": 1}, {"x": 2, "y": 4}],
    )
    conn.commit()
# Out:
# 2026-01-18 16:42:37,257 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-18 16:42:37,258 INFO sqlalchemy.engine.Engine CREATE TABLE some_table (x int, y int)
# 2026-01-18 16:42:37,258 INFO sqlalchemy.engine.Engine [generated in 0.00132s] ()
# 2026-01-18 16:42:37,261 INFO sqlalchemy.engine.Engine INSERT INTO some_table (x, y) VALUES (?, ?)
# 2026-01-18 16:42:37,262 INFO sqlalchemy.engine.Engine [generated in 0.00065s] [(1, 1), (2, 4)]
# 2026-01-18 16:42:37,263 INFO sqlalchemy.engine.Engine COMMIT

# %%
# begins once#
with engine.begin() as conn:
    conn.execute(
        text("INSERT INTO some_table (x, y) VALUES (:x, :y)"),
        [{"x": 6, "y": 8}, {"x": 9, "y": 10}],
    )
# Out:
# 2026-01-18 16:42:37,408 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-18 16:42:37,409 INFO sqlalchemy.engine.Engine INSERT INTO some_table (x, y) VALUES (?, ?)
# 2026-01-18 16:42:37,410 INFO sqlalchemy.engine.Engine [cached since 0.1488s ago] [(6, 8), (9, 10)]
# 2026-01-18 16:42:37,411 INFO sqlalchemy.engine.Engine COMMIT

# %%
# begins once#
with engine.begin() as conn:
    conn.execute(
        text("INSERT INTO some_table (x, y) VALUES (9, 10)")
            )
# Out:
# 2026-01-18 16:42:37,592 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-18 16:42:37,593 INFO sqlalchemy.engine.Engine INSERT INTO some_table (x, y) VALUES (9, 10)
# 2026-01-18 16:42:37,594 INFO sqlalchemy.engine.Engine [generated in 0.00114s] ()
# 2026-01-18 16:42:37,595 INFO sqlalchemy.engine.Engine COMMIT

# %%
# select statement#
with engine.begin() as conn:
    query_result = conn.execute(text("SELECT * FROM some_table"))
    print(query_result.all())
# Out:
# 2026-01-18 16:43:28,284 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-18 16:43:28,285 INFO sqlalchemy.engine.Engine SELECT * FROM some_table
# 2026-01-18 16:43:28,286 INFO sqlalchemy.engine.Engine [generated in 0.00050s] ()
# [(1, 1), (2, 4), (6, 8), (9, 10), (9, 10)]
# 2026-01-18 16:43:28,287 INFO sqlalchemy.engine.Engine COMMIT

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT x, y FROM some_table"))
    for row in result:
        print(f"x: {row.x} y: {row.y}")
# Out:
# 2026-01-18 17:07:15,101 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-01-18 17:07:15,103 INFO sqlalchemy.engine.Engine SELECT x, y FROM some_table
# 2026-01-18 17:07:15,104 INFO sqlalchemy.engine.Engine [generated in 0.00279s] ()
# x: 1 y: 1
# x: 2 y: 4
# x: 6 y: 8
# x: 9 y: 10
# x: 9 y: 10
# 2026-01-18 17:07:15,105 INFO sqlalchemy.engine.Engine ROLLBACK
